# %%
import numpy as np
import pandas as pd
import heapq
data = pd.read_csv('/Users/zhejindong/Desktop/Final Project Data.csv')
# Out:
# /anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2714: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pollution=['STATE','DATE']
p=list(data.head(0))[6:-8]
pollution=pollution+(list(data.head(0))[6:-8])

# %%
data['DATE']=data.DATEON.apply(lambda x:x.split(" ")[0])

# %%
data2=data.loc[:,pollution]

# %%
data2['TIME']=data.DATE.apply(lambda x:x.split("/")[0]+'-'+x.split("/")[2])
data2["MONTH"]=data.DATE.apply(lambda x:x.split("/")[0])
data2["YEAR"]=data.DATE.apply(lambda x:x.split("/")[2])

# %%
a=data2.groupby(['STATE','YEAR'])[p].mean()
b=pd.DataFrame(a)
b.to_csv("data_pollution_month.csv")

# %%
a=data3.groupby(['State','Year']).mean()
b=pd.DataFrame(a)
b.to_csv("Particle.csv")

# %%
STATE=np.unique(list(data3.State))
t=[]
NO3=[]
for i in STATE:
    index=np.argwhere(np.array(data3.State)==i)
    index=index.reshape(index.shape[0],)
    NO3.append(list(data3.iloc[index].NO3))
    t.append(list(data3.iloc[index].Year))

# %%
NO3[-4]=NO3[-4]+[0]*(len(NO3[1])-len(NO3[-4]))

# %%
b=pd.DataFrame(Particle)
b.fillna(0)
# Out:
#           0         1         2         3         4         5         6   \
# 0   2.432286  1.985973  2.225947  2.013663  1.838760  1.713705  1.724532
# 1   1.215946  1.066609  1.120584  1.185542  1.118907  1.076429  0.909305
# 2   3.077723  2.716625  2.297428  0.774595  0.752699  0.870641  0.000000
# 3   0.544899  0.471735  0.489131  0.427074  0.500718  0.454591  0.412807
# 4   1.339372  1.238225  1.055151  1.244901  1.213617  1.095035  1.140645
# 5   1.794991  1.569928  1.661394  1.444219  1.464178  1.394262  1.433111
# 6   1.099290  0.891106  0.971382  0.858912  0.857072  0.789600  0.799055
# 7   3.426569  3.145482  3.509913  3.176046  3.081393  2.829516  3.000226
# 8   2.709023  2.501632  2.836144  2.429653  2.491217  2.141223  2.302299
# 9   1.506071  1.357825  1.512602  1.352210  1.213529  1.286667  1.270275
# 10  1.900078  1.652750  1.880350  1.699308  1.642322  1.490952  1.556579
# 11  2.621592  2.077458  2.330795  2.157960  2.138478  1.939454  2.018781
# ...
